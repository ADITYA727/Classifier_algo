# %% [markdown]
# # Import Module

# %%
# read in some helpful libraries
import nltk                       # the natural langauage toolkit, open-source NLP
import pandas as pd               # pandas dataframe
import re                         # regular expression
from nltk.corpus import stopwords  
from gensim import parsing        # Help in preprocessing the data, very efficiently
import gensim
import numpy as np

# %% [markdown]
# # Read CSV

# %%
# Loading in the training data with Pandas
df_train = pd.read_csv("data_large_5000.csv")

# %% [markdown]
# # Show Data Table

# %%
# look at the first few rows and how the text looks like
print (df_train['tweets'][2]) , '\n'
df_train.head()
# Out:
#  ALE TeamIndia for the upcoming series against West Indies announced INDvWI
#                                               tweets  tagname
# 0  amp TeamIndia IndvsBan DayandNightTest PinkBal...  cricket
# 1   BharatArmyAwards Here are the nominees for th...  cricket
# 2   ALE TeamIndia for the upcoming series against...  cricket
# 3   Getting into PinkBallTest mode TeamIndia INDvBAN  cricket
# 4   Umpiring in the first ever pink ball match at...  cricket

# %% [markdown]
# # Check Dimensions ,Check Null Value and is sum and data type

# %%
## check the dimensions of the table
print ("Shape:", df_train.shape, '\n')

## Check if there is any NULL values inside the dataset
print ("Null Value Statistics:", '\n \n', df_train.isnull().sum()) ## Sum will tell the total number of NULL values inside the dataset
print ('\n')

## Explore the data types of your dataset
print ("Data Type of All Columns:" '\n \n', df_train.dtypes)
# Out:
# Shape: (35300, 2)
#
# Null Value Statistics:
#
#  tweets     0
# tagname    0
# dtype: int64
#
#
# Data Type of All Columns:
#
#  tweets     object
# tagname    object
# dtype: object

# %% [markdown]
# # Check tagname (unique)

# %%
## Collect all unique author names from author column
tag_names = df_train['tagname'].unique()
print (tag_names)
# Out:
# ['cricket' 'mobiles' 'food' 'machine learning' 'hollywood'
#  'happy birthday' 'football' 'bollywood' 'bigg boss' 'politics']

# %% [markdown]
# # Give specific id

# %%
tag_name_id = {}
assign_id = 0
for name in tag_names:
    tag_name_id[name] = assign_id
    assign_id += 1  ## Get a new id for new author
    
##  Print the dictionary created
for key, values in tag_name_id.items():
    print (key, values)
# Out:
# cricket 0
# mobiles 1
# food 2
# machine learning 3
# hollywood 4
# happy birthday 5
# football 6
# bollywood 7
# bigg boss 8
# politics 9

# %% [markdown]
# # Change key to value and value to key

# %%
id_to_tag_name = {v: k for k, v in tag_name_id.items()}
for key, values in id_to_tag_name.items():
    print (key, values)
# Out:
# 0 cricket
# 1 mobiles
# 2 food
# 3 machine learning
# 4 hollywood
# 5 happy birthday
# 6 football
# 7 bollywood
# 8 bigg boss
# 9 politics

# %% [markdown]
# # Add new column in csv

# %%
## Add a new column to pandas dataframe, with the author name mapping
def get_author_id(tag_name):
    return tag_name_id[tag_name]

df_train['tag_id'] = df_train['tagname'].map(get_author_id)

# %% [markdown]
# # Show data(after adding)

# %%
df_train.head()
# Out:
#                                               tweets  tagname  tag_id
# 0  amp TeamIndia IndvsBan DayandNightTest PinkBal...  cricket       0
# 1   BharatArmyAwards Here are the nominees for th...  cricket       0
# 2   ALE TeamIndia for the upcoming series against...  cricket       0
# 3   Getting into PinkBallTest mode TeamIndia INDvBAN  cricket       0
# 4   Umpiring in the first ever pink ball match at...  cricket       0

# %% [markdown]
# # Create Function preprocessing of data

# %%
def transformText(text):
    
    stops = set(stopwords.words("english"))
    
    # Convert text to lower
    text = text.lower()
    # Removing non ASCII chars    
    text = re.sub(r'[^\x00-\x7f]',r' ',text)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    
    # Removing all the stopwords
    filtered_words = [word for word in text.split() if word not in stops]
    
    # Removing all the tokens with lesser than 3 characters
    filtered_words = gensim.corpora.textcorpus.remove_short(filtered_words, minsize=3)
    
    # Preprocessed text after stop words removal
    text = " ".join(filtered_words)
    
    # Remove the punctuation
    text = gensim.parsing.preprocessing.strip_punctuation2(text)
    
    # Strip all the numerics
    text = gensim.parsing.preprocessing.strip_numeric(text)
    
    # Strip multiple whitespaces
    text = gensim.corpora.textcorpus.strip_multiple_whitespaces(text)
    
    # Stemming
    return gensim.parsing.preprocessing.stem_text(text)

# %% [markdown]
# # apply funtion on data

# %%
df_train['tweets'] = df_train['tweets'].map(transformText)

# %% [markdown]
# # Print data after prepossing

# %%
## Print a couple of rows after the preprocessing of the data is done

print (df_train['tweets'][0] , '\n')
print (df_train['tweets'][1] , '\n')
print (df_train['tweets'][2])
# Out:
# amp teamindia indvsban dayandnighttest pinkballtest
#
# bharatarmyaward nomine men limit perform year hurri vote
#
# al teamindia upcom seri west indi announc indvwi

# %% [markdown]
# # Split data in training data(67%) and test data(33%)

# %%
## Split the data 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_train['tweets'], df_train['tag_id'], test_size=0.33, random_state=42)
print ("Training Sample Size:", len(X_train), ' ', "Test Sample Size:" ,len(X_test))
X_train
# Out:
# Training Sample Size: 23651   Test Sample Size: 11649
# 15652    musictv hollywood xma song need right hollywoo...
# 30260    humara munna kisi kam hai kya gonnatellmykid t...
# 34761    sana fam best fandom shilpashind fam full enjo...
# 24499    okai let win tottenham awai cfc chelsea superf...
# 27857    granturco lappel chelsea devant ta contr dcisi...
#                                ...
# 16850    somebodi got stand ovat richard jewel premier ...
# 6265     fall pasta thanksgiv menu delici thanksgiv pas...
# 11284    machin learn realli technolog artificialintell...
# 860                get pinkballtest mode teamindia indvban
# 15795              mean receiv defer wwii would point govt
# Name: tweets, Length: 23651, dtype: object

# %% [markdown]
# # Building the Mode

# %%
## Get the word vocabulary out of the data
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
X_train_counts.shape

## Count of 'mistak' in corpus (mistake -> mistak after stemming)
#print ('mistak appears:', count_vect.vocabulary_.get(u'mistak') , 'in the corpus')
# Out:
# (23651, 20591)

# %%
## Get the TF-IDF vector representation of the data
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
print ('Dimension of TF-IDF vector :' , X_train_tfidf.shape)
# Out:
# Dimension of TF-IDF vector : (23651, 20591)

# %% [markdown]
# # Apply Classification

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %% [markdown]
# # Prediction

# %%
## Prediction part

X_new_counts = count_vect.transform(X_test)
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

predicted = clf.predict(X_new_tfidf)

# %% [markdown]
# # Get Result

# %%
## predictions for first 10 test samples

counter  = 0
for doc, category in zip(X_test, predicted):
    if id_to_tag_name[category] == "hollywood":
        pass
       
    print('%r => %s' % (doc, id_to_tag_name[category]))
    if(counter == 20000):
        break
    counter += 1
# Out:
# 'loos respect buddi still stick rahul jadhav know player' => football
# 'popcorn pizza blanket hollywood movi contest fun moviejunki contest action' => hollywood
# 'felic ao para otro mundo posibl solo necesitan la gana capacidad crecer aprend' => football
# 'cours pmi acp exam prep pmbok projectmanag pmiacp javascript nodej css angul' => machine learning
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'promot chelsea bad year sinc' => football
# 'articl discuss import explain examin black box horror stori transpar predict' => machine learning
# 'main area graphdatabas provid context amp detail new white' => machine learning
# 'local tourist girl vibez hollywood girlnightout joytrib style vibe maga fashion afro' => hollywood
# 'wait watch theskyispink priyankachopra priyanka priyankachoprajona nickjona' => bollywood
# 'ikeji jose mourinho yesterdai todai forev pl dont chang properchel chelsea' => football
# 'friend gui rememb film ghost insid real charm hous amp salem lot hous check' => bollywood
# 'pictur perfect famili moment abhishekbachchan aishwaryaraibachchan aradhyabachchan bollywood' => bollywood
# 'detect stock market crash topolog data analysi machinelearn' => machine learning
# 'sai happi birthdai hug box free personalis messag gift hug' => happy birthday
# 'hack relea wait inform dai leav get hina big' => bollywood
# 'congratulot hollywoodwalkoffam hollywood defygrav wick' => hollywood
# 'research berkelei ucsf school medicin develop deep learn model enabl radiolog' => machine learning
# 'slai still trend even year hinakhan amp biggboss cute nok jhok miss biggbo' => bigg boss
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'look made swoon hrithikroshan whatsyourpick bollywood' => bollywood
# 'borussia dortmund paderborn preview watch live stream kick time amp team new' => football
# 'googl new tool could help decod mysteri algorithm decid everyth machinelearn datasc' => machine learning
# 'piard robot farmer could grow food need robot agritech machinelearn agtech iot tech' => machine learning
# 'chelsea expect learn verdict appeal two window transfer ban mid decemb cfc' => football
# 'com strike kovac inter milan first chelsea goal still pend cfc' => football
# 'allrecordsundervijaysbigil make thalapathyvijai anna posit amp spread tag everywher' => food
# 'amaz wai telecom compani us artificialintellig machinelearn via' => machine learning
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'wale hungari report rate amp reaction aaron ramsei doubl seal dragon euro spot' => football
# 'kuldeep yadav teamindia member squad face ti odi start decemb' => cricket
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'time year tradit fair mean skimp pasta love' => food
# 'new machin learn algorithm offer safeti fair guarante new framework fairer safer algorithm scien' => machine learning
# 'review chi season showdown recap like hollywood new' => hollywood
# 'viernessssss felizfindesemana lo esperamo villa leyva oliva especia pizzera restaurant villa' => food
# 'hum dur hoke bhi paa hain nazdeekiyan kuchh aur hain dekha hazarao dafa fir beqarari kaisi hai sambhal sambhalta' => bigg boss
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'mp terribl mskprasad episod final hope laxman shivramakrishnan good teamindia' => cricket
# 'poitier film festiv focu indian movi focusind festiv bollywood bei' => bollywood
# 'us hashtag disruptivetech influenc twitter ytd artificialintelig fintech iot' => machine learning
# 'check newest list hollywood tell think realest' => hollywood
# 'warmest birthdai greet chief minist madhya pradesh shri wish year love peac' => happy birthday
# 'caneln rostit con salsa foie seta pastacaneln rostit con salsa foie seta pasta' => food
# 'lattaant del chelsea giroud che guadagna milioni stagion ricevuto una proposta dall inter per ing' => football
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'vintag rhineston fantail brooch hollywood glamour jewelri bling glamour luxuri rhineston premierestategalleri' => hollywood
# 'daili mail chelsea fan plot frank lampard special on banner take trip tottenham former' => football
# 'receta pasta con mejillon mui fcil rpido elaborar nada como plato pasta con punto' => food
# 'vanloon breath analyz diagnos diseas smell bigdata machinelearn' => machine learning
# 'interest challeng drive awai mid week blue tag friend help' => football
# 'mix meat pasta came someth special pasta italia foodi lover dinner magic meat' => food
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'happi birthdai ramona fun night celebr birthdayshenanigan birthdaygirl' => happy birthday
# 'manchest citi chelsea premier leagu time kick channel chelsea' => football
# 'futur spur get solid mayb even win cup trophi centuri spur' => football
# 'india senior select committe met kolkata todai pick squad upcom tour west indi' => cricket
# 'dayson best bihdai ever birthdai engag isaidy frankfurtchristmasmarket birmingham thealchemist weissbi' => happy birthday
# 'niki insta stori on year wrap kabirsingh bollywood nikitadutta' => bollywood
# 'get pinkballtest mode teamindia indvban' => cricket
# 'ram on humbl earth actress bollywood industri thank much mam' => bollywood
# 'daili mail chelsea fan plot frank lampard special on banner take trip tottenham former' => football
# 'amp hous design fiverr munar yoongi jimin wonho pogba munliv toronto jensen' => football
# 'morn vibe bumrahthegoat jaspritbumrah indiancricketteam teamindia rishabhp yorkerk' => cricket
# 'want get bodi hot katrinakaif well actress recent share glimps daili workout routin' => bollywood
# 'pum happi bihdai yugyeom focusonyugyeomdai kimyugyeom yugyeom got' => happy birthday
# 'hrithik return town hrithikroshan bollywood' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'dai jodi morri score goal cfc chelsea' => football
# 'well done girl clean sweep seri caribbean teamindia via mynt' => cricket
# 'footbal coach like slut open leg highest bidder noth like emot' => football
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'movi hellarao sent oscar effort made creat hist' => hollywood
# 'mari' => hollywood
# 'highlight superfluidworldtour latest innov interview bastian nominach' => machine learning
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'hire alert cook chino california owen bistro job pasta fish cook' => food
# 'machinelearn wai fight fraud autom machin extract known unknown patt' => machine learning
# 'remix bollywood' => bollywood
# 'hei check servic novemb chelsea mcich aguer sarri' => football
# 'tokr popcorn pizza blanket hollywood movi contest fun moviejunki contest action drama con' => hollywood
# 'happi birthdai vivek sir' => happy birthday
# 'vanloon robot learn automat artificialintellig machinelearn' => machine learning
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'python machinelearn neuralnetwork autom dataanalyt control roboticsurgeri motion planni' => machine learning
# 'black hot team firstbuzz realfirstbuzz firstbuzz bollywood actress' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'pulipaka singl cell data analysi us autoencod bigdata analyt datasci machinelearn iot iiot pytorch' => machine learning
# 'happi birthdai happi birthdai happybirthdai adamdriv happi birthdai' => happy birthday
# 'proof need hollywood nut communist insult everi american julia' => hollywood
# 'pleas give big happi birthdai shout twin minni bat amp sox year old todai' => happy birthday
# 'worst flood yr peopl dead euro need repair damag venic itali acquaaltaavenezia acquaalt' => food
# 'betfair exchang free bet bet lai lose betfair refund join' => football
# 'saba que tienda ecoagricultor tenemo mayor variedad fruta verdura ecolgica cereal' => food
# 'make weekli best work home oppoun busi' => machine learning
# 'facial recognit system make commut easier subwai tech gateless futur facialrecognit machin' => machine learning
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'dan min retrouvez redmi note dispon franc sur quad camera' => mobiles
# 'lo ltimo debutant con inglaterra fueron canterano del chelsea' => football
# 'charm enough impress snap suess bash marjaavaan sidharthmalhotra marja' => bollywood
# 'depth machin learn model best practic deeplearn machinelearn artificialintellig' => machine learning
# 'repost regrann ammuji boht dino baad' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'topnotch event pictur topnotch venda vendafollowtrain birthdai parti happybirthdai love cake wed bir' => happy birthday
# 'best macaroni chees pasta vegetarian' => food
# 'swanson return icon saturdaynight save tix websit see yall' => bollywood
# 'india senior select committe met kolkata todai pick squad upcom tour west indi' => cricket
# 'serv chicagoland homemad italian recip calzon size head famou pizza amp pasta' => food
# 'penalti master jorginho win possess season jorginho possess bal' => football
# 'radar former coach manunit chelsea josmourinho popularli known special on agre' => football
# 'top on movi seri readi big screen' => bollywood
# 'pasta meal cook amaz' => food
# 'get pinkballtest mode teamindia indvban' => cricket
# 'sondlandtestimoni hollywood look like laugh everybodi joker asaprocki' => hollywood
# 'get pinkballtest mode teamindia indvban' => cricket
# 'reserv gluten free base creat excel broth chowder soup stew bisqu sauc chowder amp enha' => food
# 'amp inaugur prestigi film festiv internationalfilmfestivalofindia light lam' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'in out predictivemodel bigdata tech analyt businessintellig' => machine learning
# 'lunch special lunchtim lunchspeci friedcalamari fishandchip burger pizza pasta ravioli' => food
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'anoth excel meal barbicanpastabar barbican plymouth best hospit delici ital' => food
# 'blog cognit servic big pictur learn get touch boldenthusiast' => machine learning
# 'analyt critic fight next gener fraud explor week blogpost know' => machine learning
# 'happi birthdai nayanthara' => happy birthday
# 'know shikhar worth open slot player like nitish rana rahul tripathi' => football
# 'shilpashind winner also call flip entertain nobodi cud recogn spirit' => bigg boss
# 'feliz cumpleao querido dio colm bendicion siempr friend birthdai suit' => happy birthday
# 'dream lasagna union station amano layer lot lot layer nonna sauc smo' => food
# 'dai roberto matteo sack chelsea forev grate champion leagu win manag' => football
# 'sanju samson get chanc futur teamindia sanjusamson indvswi' => cricket
# 'otd nov monke movi head debut hollywood new york open satir music adventur' => hollywood
# 'leeleesworld cater cater food foodtruck wed foodgram freshfood event followm' => food
# 'thank review follow love review bollywood' => bollywood
# 'rewatch right watch jess wonder rhap' => bollywood
# 'core deeplearn machinelearn via' => machine learning
# 'bee happi bright fun modernquilt featur fabul lorali ladi giftsforh giftsformom giftsforteen bir' => happy birthday
# 'cfc chelseafc chelsea' => football
# 'pasta cook dent lower glycem index pasta cook soft caf boston proudli ser' => food
# 'tak season itna push kiya gaya dusr mean physic violenc punish kiss bhi mila aur' => bigg boss
# 'futur spur get solid mayb even win cup trophi centuri spur' => football
# 'bollywood best album final poll kesari kabirsingh saaho bollywoodhungama' => bollywood
# 'delhi autumn scene chai garam cafe delhi summer goggl rickshaw uncleji food hot fresh spici' => food
# 'deewana point hina own season amp amp everi episod without ever cross line task queen amp gave' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'baaghi tigershroff new look reaction bollywood bollywoodnew bollyspi' => bollywood
# 'hot air balloon handcraft flower box order plese whatsapp' => food
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'autograph davidpastrnak boston bruin shootout gwg photo fanat coa amp hologram current' => food
# 'happi birthdai nayanthara happi birthdai nayanthara mam great dai' => happy birthday
# 'dvn alwai favourit muse thought varundhawan bollywood' => bollywood
# 'amplifi ye join fergi losangel' => hollywood
# 'wish happi birthdai vika vaibhav sir indian polic servic ip' => happy birthday
# 'war blockbust hindi tamil telugu littl edit movi bollywood cross' => bollywood
# 'erica fernand harshad chopda win big avta award function london ericafernandesinuk' => bollywood
# 'amp follow chanc win funko hollywood exclus marilyn monro pop funko pop funkohollywo' => hollywood
# 'machin learn realli depth' => machine learning
# 'colori sono come sale nell acqua della pasta danno sapor all stori che raontano' => food
# 'shayari hindipoetri poetri planet poetrycommun bollywood wednesdaywisdom' => bollywood
# 'contestalert name thing youd like starter pack watch horror movi besti mak' => hollywood
# 'get free poker plai deposit us code twenti join pokerstar new custom' => football
# 'top bollywood wed stage decor usa setup includ two fiber carv bollywood pil' => bollywood
# 'cannot get better congratul clean sweep seri caribbean teamindia' => cricket
# 'steve aoki birthdai partyvtokyo vtokyo club tokyo' => happy birthday
# 'manciti lost game chelsea side readi' => football
# 'buyest show bigg boss good good bad bad' => football
# 'happi birthdai bappi lahri novemb' => happy birthday
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'thing know arsen real madrid amp barcelona target reinier jesu footbal' => football
# 'financi cyber threat case insid bank attack tal eliyahu datasecur cybersecur' => machine learning
# 'jose mourinho join spur he finish chelsea' => football
# 'want street robber galleri millwal westham tottenham arsen chelsea brexit' => football
# 'artifici intellig need modern intellig educ bigdata blockchain robo' => machine learning
# 'pulipaka geospati platform reinforcementlearn featur pulipaka bigdata analyt datasci' => machine learning
# 'khabri bahut bdi galat fehmi hai uski wjha hit tha beta shilpashind hin' => bigg boss
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'fate royalti head hollywood royalti roll' => hollywood
# 'baban rememb amp amp gauaharkhan karishmatanna amp hinakhan bigg' => bigg boss
# 'reason trailer tanhaji theunsungwarrior enrag lefti liber amp slave sickular trailer mar' => bollywood
# 'happi bdai ananta doa terbaik dari kami selalu menyertai semoga sehat selalu panjang umur makin pin' => happy birthday
# 'gaurav fan shraddhakapoor bollywood chhichhor saaho streetdancerd baaghi prabha varundhaw' => bollywood
# 'list top two film year decad bollywood decadeend' => bollywood
# 'beauti make' => food
# 'india love instagram mumbai photographi indian delhi follow bhfyp like travel' => bollywood
# 'darbar poster rajinikanth rise score trend leaderboard movi bollywood darbar super' => bollywood
# 'pleas give big happi birthdai shout twin minni bat amp sox year old todai' => happy birthday
# 'amp follow chanc win funko hollywood exclus pop prize pack funko pop funkohollywood' => hollywood
# 'love peopl lunch todai pennoni rigati spring red onion guancial radihio cours' => food
# 'carlo benedetti compi oggi anni auguri ohio ohionotizi compleanno birthdai happybirthdai parti' => happy birthday
# 'india senior select committe met kolkata todai pick squad upcom tour west indi' => cricket
# 'jose mourinho claim tottenham transfer target bruno fernand footbal' => football
# 'teamindia readi pinkballtest indvban' => cricket
# 'love thick farmstyl shred chees like give flavor bite great homeco' => food
# 'liga inggri pekan diramaikan duel manchest citi chelsea ada juga momen kembalinya jose mourinho tepi lapang' => football
# 'readi lethal trio readi pinkballtest teamindia indvban' => cricket
# 'old daysgen kelli memor scene classicsing rain hollywood music movi nostalgia' => hollywood
# 'hat fight hunger item collect far northland christma store pasta amp ricedri' => food
# 'love thick farmstyl shred chees like give flavor bite great homeco' => food
# 'learn make pasta cfa opal cook pasta' => food
# 'happi birthdai scorpio self birthdai happybirthdaytom happybirthdai happi birth year' => happy birthday
# 'depend never let madhuridixit goodmorn asimriaz bringba' => bollywood
# 'happi birthdai sushmita sen' => happy birthday
# 'try sound hollywood sound hollywoodadjac mooooooooooov peddl' => hollywood
# 'good come conclus hollywood love hear vain' => hollywood
# 'els hollywood swipe south border mask mayan god camazotz bat god death' => happy birthday
# 'two tonight though yr old make debut help team win big futur gre' => football
# 'lezzetli bir festival hazr msnz aralk tarihlerind koca uluslarara fuar merkezi nde' => food
# 'india squad west indi seri teamindia bcci westindia viratkohli shikhardhawan klrahul' => cricket
# 'india sid sister bol rahe hai sid' => bollywood
# 'network prometeo develop artifici intellig platform monitor firefight health zdnet machi' => machine learning
# 'rohit good new teamindia rohit indvssa indvsa rohitopensagain' => cricket
# 'harri microsoft launch xcloud control stream wai bigdata machinelearn' => machine learning
# 'truli unexpect never thought would love contest like shilpashin' => hollywood
# 'achajimainhari remix bollywood' => bollywood
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'role machinelearn bbecommerc could benefit ebusi find' => machine learning
# 'tak season itna push kiya gaya dusr mean physic violenc punish kiss bhi mila aur' => bigg boss
# 'sposupd teamindia indv' => cricket
# 'cineplex asli action hero ladta hain dushman barbadi liy dekhiy actionblast film festiv novemb' => bollywood
# 'bollywood massiv islamophobia problem right need stop serious stop' => bollywood
# 'cucinabenedetta fusilli porcini gamberetti insiem sapor delicati facili grand effetto ricett cuc' => food
# 'hina khan debut film hack got releas date need know hinakhan hina' => bollywood
# 'happi birthdai alluarha staybless' => happy birthday
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'readi lethal trio readi pinkballtest teamindia indvban' => cricket
# 'requir bit work delici agnolotti recip definit worth effort' => food
# 'india bangladesh readi make histori much await dai night test match readi playbold' => cricket
# 'otd nov monke movi head debut hollywood new york open satir music adventur' => hollywood
# 'best teamindia give best win match make fan happi make doubl hundr' => cricket
# 'rich satisfi weeknight spaghetti bolognes take minut start finish simpl' => food
# 'want get bodi hot katrinakaif well actress recent share glimps daili workout routin' => bollywood
# 'artificialintellig machinelearn datasci iot robot execut interview robert joseph direct' => machine learning
# 'charm enough impress snap suess bash marjaavaan sidharthmalhotra marja' => bollywood
# 'deeplearn high demand popular check reason behind machin' => machine learning
# 'dish histori mani variat color motif tast textur subtleti dish pasta' => food
# 'com strike kovac inter milan first chelsea goal still pend cfc' => football
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'offshor bank target phinea fisher confirm hack cybersecur databreach hack' => machine learning
# 'bollywood fool world year social media reveal real face hatefool major new' => bollywood
# 'squash season find ingredi warm pasta dish local farm' => food
# 'happi birthdai mani mani return dai sir' => happy birthday
# 'boulder denver economi highli suscept disrupt artifici intellig denver post read' => machine learning
# 'darbar poster rajinikanth rise score trend leaderboard movi bollywood darbar super' => bollywood
# 'belat happi birthdai nayanatara garu' => happy birthday
# 'abhi bhi hindhu muslim chal rha hai hina muslim dipika hindu muslim asim muslim kya hua yeh muslim' => bigg boss
# 'worldpastadai take time understand nutrit behind tasti comfort carbohydr sourc' => food
# 'celeb celebr celebr celebstyl bollywood film movi' => bollywood
# 'tak season itna push kiya gaya dusr mean physic violenc punish kiss bhi mila aur' => bigg boss
# 'robot humanoid emot artificialintellig robot robot machinelearn fac' => machine learning
# 'thesh chelsea' => football
# 'ahrar priyank elimin reason sidharth westandbyasimriaz' => bigg boss
# 'vinciamo emiliaromagna parma apriremo una grand azienda pasta che porter madeinitali giro' => food
# 'cosa meglio semplic spaghetton filetto pomodoro pasta gragnano pomodorini del piennolo' => food
# 'mf translat happi birthdai dad take care health wonder year ahead happybirthdai famili' => happy birthday
# 'sposupd teamindia indv' => cricket
# 'chc mng sinh nht nha yumi happi birthdai mun yumi twt' => happy birthday
# 'pata nhi aisa kart hain wale salman also sai co bhi shil' => bigg boss
# 'swetha wish happi birthdai nayanthara lot love happi bless reach todai fan' => happy birthday
# 'margherita pasta like pasta' => food
# 'pregunta hace cuatro ao estando chelsea ust dijo que nunca vendra dirigir tottenham porqu amaba demasiado' => football
# 'sara ali khan look exhilar cover girl saraalikhan beauti stun style fashion song' => bollywood
# 'piard robot farmer could grow food need robot agritech machinelearn agtech iot tech' => machine learning
# 'cook cook lunch' => food
# 'quot train self drive car selfdrivingcar autonomousvehicl' => machine learning
# 'list top indian celebr highest brand valuat reveal overal brand valu' => bollywood
# 'martin atkinson offici chelsea game manchest citi saturdai mcich cfc' => football
# 'readi lethal trio readi pinkballtest teamindia indvban' => cricket
# 'tonight viper room present special guest door' => hollywood
# 'happi place penguin disnei disneyland birthdai franc pari romant happi fun love' => happy birthday
# 'apart debut film badboi namashichakraborti amp amrinqureshi gainingspotlight fashi' => bollywood
# 'scroll found pictur togeth rememb' => bollywood
# 'outfit pinnacl shrutisancheti jewelri minerali store style wore' => bollywood
# 'perch nostra cannuia sta proprio bene noplast sostenibilit pastastraw pasta drinkitalian' => food
# 'piard cute robot help kid learn code math languag music via robot robot machinelearn' => machine learning
# 'daili mail chelsea fan plot frank lampard special on banner take trip tottenham former' => football
# 'pulipaka deepclust singl cell rna seq data bigdata analyt datasci machinelearn iot iiot pytorch python' => machine learning
# 'sposupd teamindia indv' => cricket
# 'bollywood zero ethic saddest part metaphor blind public pellet' => machine learning
# 'worst flood yr peopl dead euro need repair damag venic itali acquaaltaavenezia acquaalt' => food
# 'chelsea expect learn verdict appeal two window transfer ban mid decemb cfc' => football
# 'sanju samson get chanc futur teamindia sanjusamson indvswi' => cricket
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'heirloom tomato anglolotti lobster cream butter king crab oregano pasta anglolotti caputoflour' => food
# 'movi award ladi supper star nayanthara happi birthdai mam' => happy birthday
# 'chelsea transfer ban appeal heard court arbitr sport tomorrow everyth' => football
# 'indian movi bollywood new pooja hegd cross million mark insta' => bollywood
# 'hina khan share hack photo glamsham bollywood hack' => bollywood
# 'veriveri veriveri happi birthdai' => happy birthday
# 'cyfirma predict cyber threat visibl intellig analyt platform compani back goldman sach' => machine learning
# 'need peopl first strategi artificialintellig machin' => machine learning
# 'redmi note pro ama yonjari akuppa marol damak makha link sida nattraga eikhoigi leiba yonba android app' => mobiles
# 'kritisanon rare interest role actress land meati part bachchanpandei opposit' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'radh updat radh salmankhan biggboss winner gautamgulati' => bollywood
# 'josi canseco showcas free peopl bikini collect freepeopl hollywood' => hollywood
# 'com strike kovac inter milan first chelsea goal still pend cfc' => football
# 'get big discount blackfridai blackfridai best uniti tutori beginn train cours' => machine learning
# 'video make enterpris hyper product cognitiveautom intelligentautom' => machine learning
# 'lunch verdepiatto' => food
# 'cajun alfredo pasta make kellybcook dinner dinneridea pasta cajunfood' => food
# 'donga indian thriller director kodandarami reddi bollywood india golimar' => bollywood
# 'digitrax see similar song machinelearn artificialintellig' => machine learning
# 'everydai hustl get tire ye give order favorit flavor' => food
# 'happi birthdai happybirthdaykartikaaryan kartikaaryan hbdkartikaaryan happybdaykartikaaryan' => bollywood
# 'tallarin fresco con hongo salsa tomat queso parmesano rallado una autntica delicia para' => food
# 'daili mail chelsea fan plot frank lampard special on banner take trip tottenham former' => football
# 'biggest star bollywood first poll salmankhan shahrukhkhan hrithikroshan akshaykumar' => bollywood
# 'hollywood move far left gut stand belief spite risk' => hollywood
# 'swetha wish happi birthdai nayanthara lot love happi bless reach todai fan' => happy birthday
# 'shilpashind remain hot new continu like fan chase ppl journalist invit' => bigg boss
# 'gaurav shraddhakapoor bollywood chhichhor saaho streetdancerd baaghi prabha varundhawan susha' => bollywood
# 'actriz jennif lpez revel que trabajo polmica pelcula hutler fue remunerado debido que int' => hollywood
# 'interest scientist us artificialintellig ensur stem cell good enough patient artificialintelli' => machine learning
# 'londra pizza pasta chiesa diavola illoto' => food
# 'pasta pizza' => food
# 'felt realli proud amp realli bad rule applic' => machine learning
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'big batch beef ragu pasta easili feed peopl make ragu ahead time reheat' => food
# 'mauricio pochettino leav tottenham hotspur less month champion leagu final' => football
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'john belushi tri fire frat brother comedi classicn lampoon anim hous hollywood comedi' => hollywood
# 'actual support actor oscar take look bollywood celebr' => bollywood
# 'decemb cfc chelsea' => football
# 'tout mon enfanc budspenc budspencerterencehil pasta pasta pastalov pastafood foodporn food' => food
# 'look though katrinakaif bollywood' => bollywood
# 'tottenham club mediocr son ganador siempr estarn sombra del chelsea mourinho' => football
# 'india senior select committe met kolkata todai pick squad upcom tour west indi' => cricket
# 'feliz cumpleao querida dio colm luz bendicion siempr birthdai' => happy birthday
# 'spaghetti allo scoglio sempr squisiti grand effetto perfetti ogni oasion ric' => food
# 'machin learn python cheatsheet bigdata analyt machinelearn datasci iot iiot python rstat' => machine learning
# 'know thing tast best made kitchen home top chicken breast hot sauc chi' => food
# 'let testcricket ultim winner teamindia bcci daynighttest pinkballtest' => cricket
# 'green new custom offer bet get aumul bet join new custom' => football
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'wonder happi healthi birthdai forev happybirthdai vikadakavi best wish shaz dyn' => happy birthday
# 'bbseason contest behav like popular season contest rashmi shilpa shinda sidharth' => bigg boss
# 'india senior select committe met kolkata todai pick squad upcom tour west indi' => cricket
# 'happi birthdai' => happy birthday
# 'game throne season episod amp quot long night amp quot watch throne like' => hollywood
# 'pleas give big happi birthdai shout twin minni bat amp sox year old todai' => happy birthday
# 'white sauc pasta creami pasta white sauc veget chicken mimi kitchen see bit' => food
# 'happi birthdai son jayvion babi bdai birthdai birthdayboi boi caribbean' => happy birthday
# 'misheard song lyric blind light catmem live funni trend drivel impeach' => bollywood
# 'bcci annouc squad indvswi fan vouch bringbackdhoni viratkohli sai pink ball nobal troub' => cricket
# 'determin machinelearn right compani get practic guidanc build smart strategi start' => machine learning
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'india becom world leader artificialintelliegnc vishal sikka hindu artifici' => machine learning
# 'pleas check real hip hop music amp follow viciousseason sincerelyvici' => hollywood
# 'pleas give big happi birthdai shout twin minni bat amp sox year old todai' => happy birthday
# 'midnight birthdai surpris birthdai boi head back town happybirthdai' => happy birthday
# 'visual learn read bigdata' => machine learning
# 'robot psychologist next big app machinelearn robot psycholog via' => machine learning
# 'trend trend decad research infograph cybersecur machinelearn devop analyt cio iot' => machine learning
# 'com strike kovac inter milan first chelsea goal still pend cfc' => football
# 'impact chatbot person appdevelop messag transform' => machine learning
# 'great talk tim wang aeler neuroimag analysi machinelearn particularli multipl sclero' => machine learning
# 'india srilanka test india draw india srilanka odi' => cricket
# 'pleas give big happi birthdai shout twin minni bat amp sox year old todai' => happy birthday
# 'pregunta hace cuatro ao estando chelsea ust dijo que nunca vendra dirigir tottenham porqu amaba demasiado' => football
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'special thank activechef promot healthi eat activ lifestyl bud chef' => food
# 'happi happi birthdai dear brother arya ravi wish fantast year ahead' => happy birthday
# 'light lunch properport flexiblediet carbcycl iifym intermittentfast steak octopu pasta mel' => food
# 'primero partido mourinho tottenham westham olympiaco bournemouth' => football
# 'pulipaka azur machin learn algorithm cheat sheet bigdata analyt datasci machinelearn iot iiot pytorch' => machine learning
# 'pandit jawaharlalnehru leader influenc fellow leader amp great person inspir nurtur tini litt' => happy birthday
# 'happi birthdai todai celebr year provid nh worker aess save' => happy birthday
# 'vanloon digitaltransform advantag learn iot' => machine learning
# 'india senior select committe met kolkata todai pick squad upcom tour west indi' => cricket
# 'smart digit life infograph smartciti iot bigdata cybersecur healthcar educ infosec machinelearni' => machine learning
# 'ancora fame hungri dinner food eatingout cookingskil pasta carb feedm diet' => food
# 'love tuck pasta lunch' => food
# 'hei thalaivar fan seen front page headlin top maharashtra newspap power' => bollywood
# 'cuti rakul hot team firstbuzz realfirstbuzz firstbuzz bollywood actr' => bollywood
# 'futur healthtech compani lead pack machinelearn intoainew' => machine learning
# 'abdulhakimjoi spotlightactor abdulhakim imdb britishbangladeshi bengaliactor celebr actor model abdulhakim' => bollywood
# 'happi children dai child smile happi world beauti funni enjoi nehruji birthdai celebr' => happy birthday
# 'breath analyz diagnos diseas smell health healthtech digitalhealth healthcar medt' => machine learning
# 'travertin floor repolish beckenham todai langleypark westwickham hay balham chelsea' => football
# 'dai nemanja matic made debut cfc chelsea' => football
# 'check pictur bollywood lovebird offici pagalpanti promot' => bollywood
# 'moment best captain aord vote championsleagu viratkohli msdhoni rohitsharma kingkohli' => bollywood
# 'recett via jasminecuisin salad pte froid fruit jacquier style thon vgane sal' => food
# 'troubl glamour town romanc thrive old hollywood murder amp corrupt' => hollywood
# 'new gmail featur remind attach file type attach machinelearn' => machine learning
# 'happi birthdai bring happi birthdai happybirthdai balloon nobirthdaycak cheesecak lip' => happy birthday
# 'get pinkballtest mode teamindia indvban' => cricket
# 'rnbmusic mixtap mixtap upcomingartist produc studio radiost musicproduc singersongwrit' => hollywood
# 'icymi star trek star war rise abram opinion starwar film episod' => bollywood
# 'happi birthdai friend' => happy birthday
# 'game throne episod discuss seeason episod like hollywood new' => hollywood
# 'lot duck pair chines style blue white estim lotsroad lotsroadauct' => food
# 'sposupd teamindia indv' => cricket
# 'offici whatsyourpick special favorit nation film award win rustom pavri navi' => bollywood
# 'actor star sever hit hijack idea narrat struggler bollywood' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'welcom india bollywood filmi actor come india' => bollywood
# 'oggi worldpastadai buona sana sostenibil perch pasta alimento del futuro tra anni immagi' => food
# 'decemb cfc chelsea' => football
# 'tak season itna push kiya gaya dusr mean physic violenc punish kiss bhi mila aur' => bigg boss
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'nutshel machinelearn project three main part data understand data gather amp clean' => machine learning
# 'write wai anoth life annpatchett act writerslif screenwrit hollywood book write film' => hollywood
# 'bollywood massiv islamophobia problem right need stop serious stop' => bollywood
# 'india senior select committe met kolkata todai pick squad upcom tour west indi' => cricket
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'pleas give big happi birthdai shout twin minni bat amp sox year old todai' => happy birthday
# 'mourinho tottenham faltou coerncia tica por part portugu mourinho tottenham premierleagu' => football
# 'daili mail chelsea fan plot frank lampard special on banner take trip tottenham former' => football
# 'autograph davidpastrnak boston bruin shootout gwg photo fanat coa amp hologram current' => food
# 'creami risotto perfect winter warmer chilli mondai afternoon drop kid make' => food
# 'recycl turn technolog combin comput vision machinelearn robot autom' => machine learning
# 'abdulhakimjoi spotlightactor abdulhakim imdb britishbangladeshi bengaliactor celebr actor model abdulhakim' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'bigg boss weekendkavaarwithsalman updat johnabraham amp anilkapoor set weekendkavaar movi pro' => bigg boss
# 'alwai someth delici eat margheritariyadh riyadh food itali' => food
# 'monikalang check aaradhyabachchan birthdai parti pictur turn todai bollywood photogalleri' => bollywood
# 'plu chelsea nach einspruch entscheidung ber transfersperr fllt krze ca urteil binnen drei wochen bekanntg' => football
# 'arrei sambar call paper paper present symposium invit develop peer review' => bollywood
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'new algorithm train avoid specif bad behavior robot artificialintellig machinelearn techn' => machine learning
# 'cold weather comfortfood fresh tomato organ spinach fresh shrimp onion garlic' => food
# 'loot popio temper glass screen protector xiaomi redmi note pack worth offer price' => hollywood
# 'daili mail chelsea fan plot frank lampard special on banner take trip tottenham former' => football
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'new busi quot losangel motivationalspeak bollywood love logist inspir' => hollywood
# 'download latest bollywood hollywood movi free sharemovi xmoviesxyz xmovi bengalimovi' => bollywood
# 'happi birthdai' => happy birthday
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'interest get know italian food littl better gelato begin itali italianf' => food
# 'advic your kind environ watch facial express your' => machine learning
# 'aord current situat india bollywood govern even supremecourt troubl' => bollywood
# 'eden hazard chelsea season far chelsea parti without' => football
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'tra convertirs nuevo entrenador tottenham recordamo frase que dijo mourinho cuando todava era' => football
# 'pasta forno con cavolfior una pietanza semplic molto saporita per ricetta' => food
# 'receta pasta tiburn con tomat jamn serrano aceituna negra plato salud mui sencillo con sabor ital' => food
# 'nonu happi birthdai kind fun amp crazi boi princ' => happy birthday
# 'happi bihdai' => happy birthday
# 'kartik bhumi ananya groov recreat version ankhiyon goli mare bollywood bollywoodnew' => bollywood
# 'cabl berri drop ear parti partyloud dancehal riddim' => hollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'got miui updat redmi note pro redmi xiomi redminotepro' => mobiles
# 'bliss inspir experi far big shoutout awesom opportunit' => food
# 'inter giroud depaul incontro con lagent dellattaant del chelsea scelta cont ragiona cifr' => football
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'hei check servic novemb chelsea mcich aguer sarri' => football
# 'cineplex nahin pata tha watch mainhoonna aaj shaam baje sirf colorscineplex par filmeinmusthain bollywood' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'noth fanci tonight spaghetti dinner pasta spaghetti favorit yummi statenisland nyc' => food
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'italiantast italiantast week italin cuisin world almost end fridai cavatelli' => food
# 'machin learn algorithm explain artificialintellig businessanalyt bigdata' => machine learning
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'lock date april upcom untitl movi bollywood bollywoodnew apri' => bollywood
# 'kuldeep yadav teamindia member squad face ti odi start decemb' => cricket
# 'osaka namba bakeri pizza pasta beer wine' => food
# 'pulipaka download ebook page pdf algebra differenti calculu computersci amp machinelearn bigdata' => machine learning
# 'happi weekend cook pasta food fridayfeel buonappetito' => food
# 'dai jodi morri score goal cfc chelsea' => football
# 'sander berg genk wonderkid target liverpool chelsea sander berg chelsea' => football
# 'ima tell kid hugh hefner playboi mansion lol lmao impeach donaldtrump melaniatrump' => hollywood
# 'well deserv imagin hollywood actor love countri rariti deserv medal' => hollywood
# 'hopefulli fit saturdai cfc chelsea' => football
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'happi birthdai rajkumar hirani myauskar bollywood rajkumarhirani' => bollywood
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'complet free spin wager requir match bonu join chilli casino' => football
# 'manciti lost game chelsea side readi' => football
# 'teamindia readi pinkballtest indvban' => cricket
# 'tbt hollywood thursdaymorn hollywood bossladi smile tbthursdai actor viacom positivethink' => hollywood
# 'indian movi bollywood new saif ali khan alaia furniturewala starrer jawaani jaaneman fresh' => bollywood
# 'good writer talent distract internet anon write hollywood' => hollywood
# 'jeito que amo comemorando meu aniversrio aniversario happybirthdai birthdai felizaniversario' => happy birthday
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'ryan bolchoz pleas help wish friend colleagu joshua ryan bolchoz happi birthdai best' => happy birthday
# 'pagalpanti part stai tune thekapilsharmashow tkss comedi' => bollywood
# 'eden hazard full faith chelsea get result manchest citi saturdai mcich' => football
# 'interest read interest code explan also directli' => machine learning
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'pte aux courgett truff lamel grison itali pasta food foodporn yum instafood yummi amaz' => food
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'prithvi soni painter origin icon bollywood poster visit cinemaazi studio todai meet team' => bollywood
# 'com strike kovac inter milan first chelsea goal still pend cfc' => football
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'redmi note redmi poco cooker redmi appl huawei samsun via' => mobiles
# 'carli chelsea atletico napoli pronti fare folli per barella nainggolan non abbiamo pensato' => food
# 'know harriet tubman heroic black woman act democrat slaveown julia robert' => hollywood
# 'hei thalaivar fan seen front page headlin top maharashtra newspap power' => bollywood
# 'pulipaka gpu chip expect notebook bigdata analyt datasci machinelearn iot iiot pytorch' => machine learning
# 'birthdai bdai parti instabdai bestofthedai birthdaycak cake friend celebr photoofthedai instagood' => happy birthday
# 'note asylum pezoutlaw hollywood psycho luci netflix pezoutlaw amazon' => hollywood
# 'lampard mourinho look forward on chelseafc cfc chelsea' => football
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'todai margarita amp ang birthdai come get product todai conexinsalonandspa' => happy birthday
# 'tri chicken club pizza yet must try stop dine pickup order' => food
# 'see virtual tour list van buren hollywood realest' => hollywood
# 'dai roberto matteo took charg last game cfc chelsea' => football
# 'twitter react mauricio pochettino leav tottenham hotspur month ucl final' => football
# 'welcom pasta world cook food pasta buonappetito lovefood' => food
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'semplic appetitoso veloc preparar primo piatto perfetto scopri' => food
# 'bee happi bright fun modernquilt featur fabul lorali ladi giftsforh giftsformom giftsforteen bir' => happy birthday
# 'craziest lot iv seen trede kudo everyon love rashami desai' => bigg boss
# 'sposupd teamindia indv' => cricket
# 'architect modern algorithm algorithm programm computersci scienc comput program' => machine learning
# 'get pinkballtest mode teamindia indvban' => cricket
# 'india senior select committe met kolkata todai pick squad upcom tour west indi' => cricket
# 'pregunta hace cuatro ao estando chelsea ust dijo que nunca vendra dirigir tottenham porqu amaba demasiado' => football
# 'follow along senior softwar engin jordan thayer seri problem solv artificialintellig' => machine learning
# 'beauti redefin katrinakaif versatil stunner beauti gorgeou style fashion beauti stun movieta' => bollywood
# 'warmest birthdai greet chief minist madhya pradesh shri wish year love peac' => happy birthday
# 'mp terribl mskprasad episod final hope laxman shivramakrishnan good teamindia' => cricket
# 'combin favorit retweet dhoni raina favorit rohit kohli ipl ipl iplauct' => cricket
# 'che ide originali dietamediterranea pasta' => food
# 'artificialintellig transform financialmarket read insight impactbrief' => machine learning
# 'dai experi letter far think happen dabbl number find' => machine learning
# 'bhagat modi' => bollywood
# 'galan hollywood que lo ao pasan factura' => hollywood
# 'goodmorningfriend possitivethought possitivevib awesom breakingnew thursdaymotiv thursdaythought' => hollywood
# 'jose mourinho becom new manag tottenham despit sai back could never manag club' => football
# 'busi dress run place regga itun applemus' => hollywood
# 'sharma guess think tbt throwback firstphotoshoot bollywood' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'list pick captain todai histor test match choic make list plai' => cricket
# 'happi birthdai love daughter shanaya make proud hard work delig wai god bless alwai' => happy birthday
# 'episod magic time live hollywood life guest hawk koch listen' => hollywood
# 'pizzeria yuiciroa' => food
# 'mourinho spent inflat adjust chelsea player manchest unit might' => football
# 'huge insid jollibe northgat shop centr winnipeg spaghetti chicken wpgnow' => food
# 'voic world write sportsand vlogdaili check' => hollywood
# 'deeplearn neural network context base understand realiti differenti' => machine learning
# 'hero need hollywood life trap liter metaphor' => hollywood
# 'happi birthdai sweet momma' => happy birthday
# 'spaghetti squid bottarga give littl bit time edit video asap' => food
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'jose mourinho join tottenham hotspur replac mauricio pochettino month decemb face' => football
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'raider scuse put leash holder tab thank thursdai giveadogabon hollywoodfe hollywood dog' => hollywood
# 'appli machin learn advanc photon sourc aeler complex machinelearn intoainew' => machine learning
# 'india bangladesh readi make histori much await dai night test match readi playbold' => cricket
# 'pulipaka machinelearn book help level data scientist bigdata analyt datasci iot iiot pyt' => machine learning
# 'pilot brand new resourc rasa develop crowd sourc open repositori nlu train data help' => machine learning
# 'sunglass run place manag execut mba' => hollywood
# 'dai chelsea nottingham forest ian britton score first half equalis header' => football
# 'kiara brought funki twist wardrob late recent out show actress flaunt' => bollywood
# 'smart digit life infograph smartciti iot bigdata cybersecur healthcar educ infosec machinelearni' => machine learning
# 'tonight special rossini buffaloshrimp stuffedclam burrata fresh littleneckclam pasta carbonara' => food
# 'darbar poster rajinikanth rise score trend leaderboard movi bollywood darbar super' => bollywood
# 'happi worldtelevisiondai ratankgupta rkg filmcrit journalist writer rkgmoviereview therkgshow' => bollywood
# 'lord menu pic pasta noodl meatbal chicken foodi foodi' => food
# 'big batch beef ragu pasta easili feed peopl make ragu ahead time reheat' => food
# 'dear california never forget fuck idiot removehim nevernun votehimout resign' => hollywood
# 'chelsea appeal court arbitr sport ca current heard outcom decid' => football
# 'histori made eden garden todai teamindia first ever dai night pinkballtest get watch' => cricket
# 'chelsea appeal heard tomorrow ban lift cfc' => football
# 'pasta patat tradit food napl sort soup perfect cold dai stayhungrystayfoodi' => food
# 'tre principio diseo centrado la persona para aplicar machinelearn' => machine learning
# 'guyz watch trailer upcom bollywood film trailer like comment goodneww' => bollywood
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'lasagna anyon beef lasagna ricotta layer ewi gewi good pasta lasagna chees beef' => food
# 'piard robot farmer could grow food need robot agritech machinelearn agtech iot tech' => machine learning
# 'daili mail chelsea fan plot frank lampard special on banner take trip tottenham former' => football
# 'exposethetruth world watch wakeup sheknew illuminatiagenda hollywood' => hollywood
# 'happi birthdai' => happy birthday
# 'vanloon workspac perform work cloud prem hybrid vanloon citrixpartn' => machine learning
# 'silver cat ring fashion style love instagood like ootd moda fashionblogg model photogr' => happy birthday
# 'teamindia readi pinkballtest indvban' => cricket
# 'hawttttawesom emraanhashmi snap promot upcom film thebodi juhu bollywood' => bollywood
# 'sesam chicken asparagu pasta food recip cook pasta' => food
# 'tonight kingston allyoucaneat pasta pastafiestaja theterraceja call whatsapp' => food
# 'jame kincaid head list hollywood stardust fade glitter remain peopl care begin dyi' => hollywood
# 'bollywood salmankhan dabanngtrail' => bollywood
# 'regist start predict note winner chosen screen attende' => machine learning
# 'happi birthdai stanbrook commun move yorkshir worcest brand new build' => happy birthday
# 'pasta pasta vuol dire anch innovazion fra anni tagliatel alla spirulina pennett agli insetti stampat non' => food
# 'cannot get better congratul clean sweep seri caribbean teamindia' => cricket
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# ...
# 'darbar poster rajinikanth rise score trend leaderboard movi bollywood darbar super' => bollywood
# 'want street robber galleri millwal westham tottenham arsen chelsea brexit' => football
# 'cannot get better congratul clean sweep seri caribbean teamindia' => cricket
# 'dai bet legend retir footbal club app' => football
# 'intel unveil first chip built cloud technolog artificialintellig tech machinelearn' => machine learning
# 'sale sale sale sale cant sai enough come black fridai hff sale complex hollywood' => food
# 'india halt watch zee rangbaaz phirs trailer gut gun glori' => hollywood
# 'yxx yoshikichannel yoshiki happi birthdai' => happy birthday
# 'chelsea new live hazard back blue beat citi utd liverpool gelhardt race hudson odoi' => football
# 'sidharthshukla best player bigg boss' => bigg boss
# 'hollywood actress babi grew clone children favor' => hollywood
# 'happi birthdai wish honbl governor uttar pradesh smt aanandiben patel prayer long healthi' => happy birthday
# 'video star kid share social media cant help blush abram bring inner artist' => bollywood
# 'darbar poster rajinikanth rise score trend leaderboard movi bollywood darbar super' => bollywood
# 'sposupd teamindia indv' => cricket
# 'bollywood entri bollywood yesaliaashiqui vardhanpuri shivalika' => bollywood
# 'tanhaji trailer controversi' => bollywood
# 'anyon got good pasta recip' => food
# 'hollywood' => hollywood
# 'jose mourinho join spur he finish chelsea' => football
# 'historia que inspiran campen del mundo liga sencillo gran corazn demostrando ftbol cada vez' => food
# 'jesseca harri happi birthdai' => happy birthday
# 'ador dont try beat actual beat everi singl trend fandom dude even half sidheart' => bigg boss
# 'pulipaka deepclust singl cell rna seq data bigdata analyt datasci machinelearn iot iiot pytorch python' => machine learning
# 'wwe amp bollywood come togeth fun watch dvn chat thequeen exclus' => bollywood
# 'pandit jawaharlalnehru leader influenc fellow leader amp great person inspir nurtur tini litt' => happy birthday
# 'indian movi bollywood new jacquelin fernandez confirm film john abraham rakul preet singh' => bollywood
# 'got perfect backdrop date night special oasion capuanoristorant flemingtonnj njeat' => bollywood
# 'com strike kovac inter milan first chelsea goal still pend cfc' => football
# 'stack tonnarelli readi night fyi dolli underneath viaperla viaperlabould pasta' => food
# 'free bet bet redeem credit free bet join william hill new cust' => football
# 'pandit jawaharlalnehru leader influenc fellow leader amp great person inspir nurtur tini litt' => happy birthday
# 'japan tokyo hakata ramen yummi yum lunch dinn' => food
# 'love shot freshli made pasta made scratch incred chef morn enjoi' => food
# 'chicken parmesan penn pasta pictur turn great meal amaz favorit meal famili chic' => food
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'redmi note espaa xiaomi' => mobiles
# 'vanloon creat mani job kill last year read' => machine learning
# 'la protagonista frozen unen paseo fama hollywood hollywoodwalkoffam kristenbel idinamenzel' => hollywood
# 'stop algorithm act poor tast understand artificia' => machine learning
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'second whitenois hollywood' => hollywood
# 'look like sanju samson alwai utilis player teamindia' => cricket
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'sharma guess think tbt throwback firstphotoshoot bollywood' => bollywood
# 'best wish worldhellodai ratankgupta filmcrit journalist writer rkgmoviereview therkgshow' => bollywood
# 'combin favorit retweet dhoni raina favorit rohit kohli ipl ipl iplauct' => cricket
# 'happi birthdai nola born nyc base musician former maccno board member camil lena' => happy birthday
# 'pulipaka demystifi machinelearn power tool datadriven world bigdata analyt datasci iot iiot' => machine learning
# 'gran dia gran proyecto data machinelearn' => machine learning
# 'vanloon aiot emerg futur industri learn iot bigdata machin' => machine learning
# 'love thick farmstyl shred chees like give flavor bite great homeco' => food
# 'dilbar dilbar inform return bollywood via' => bollywood
# 'cineplex pyaar mohobbat dhokha hai bhaag beta mauka hai filmeinmusthain colorscineplex bollywood marriag marria' => bollywood
# 'breath analyz diagnos diseas smell health healthtech digitalhealth healthcar medt' => machine learning
# 'check know aamirkhan wiki height weight ag famili girlfriend wife cast imag amp' => bollywood
# 'china defeat team elit doctor speed auraci rate round brain tumor diagnosi artif' => machine learning
# 'fav actor bollywood follow beacus' => bollywood
# 'fashion art artist design newyork california vega reno london nike chicago lasvega sandiego' => hollywood
# 'machin learn realli technolog artificialintellig tech machinelearn iot bigdata blockchain' => machine learning
# 'amp follow chanc win funko hollywood exclus pop prize pack funko pop funkohollywood' => hollywood
# 'happi birthdai happi birthdai happybirthdai shailenewoodlei happi birthdai' => happy birthday
# 'let get know world jumanjithenextlevel' => hollywood
# 'beauti isernia itali pour rain cold small eateri offer much warmth' => food
# 'poach egg ooz black forest ham smoke bacon tagliatel salt egg yolk shave side garlic' => food
# 'hollywood move far left gut stand belief spite risk' => hollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'view room radheradh bollywood kanpurboi singer music artist gig perform' => bollywood
# 'deve partir dai grandi cambiamento noplast sostenibilit pastastraw pasta drinkitalian' => food
# 'curvi critic aveng endgam wendi lee szani like hollywood new' => hollywood
# 'camaron comienza fiesta para pasta shrimp shrimppasta pasta pastalov tasti yum elegua best' => food
# 'willian understood delai contract talk chelsea hope receiv offer barcelona' => football
# 'intel neural comput stick artificialintellig deeplearn machinelearn via' => machine learning
# 'last christma dai space avail book avoid disappoint newtonlewillow' => hollywood
# 'clsico italiano canelon ricotta spinaci reserva web tel' => food
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'even mix pasta tuna tasti lunch pasta lunch foodi itali fish italian euro' => food
# 'voic search futur chatbot bot artificialintelligenc' => machine learning
# 'front page dailyexpress sport edicola primapagina arsen chelsea liverpool spur' => football
# 'repost ofword via trust love epicquot quotesdaili quot quotesofthedai lovequot' => hollywood
# 'feel good whenev man back field matter team love see area alw' => football
# 'yuta rico happi birthdai week happi happybirth' => happy birthday
# 'spaghetti con aiugh oliv pomodori recip pasta soogood recip' => food
# 'dai roberto matteo took charg last game cfc chelsea' => football
# 'birthdai girl gradschoolfriend birthdaygirl harrypotterbirthdaycak goldensnitch smilei happi' => happy birthday
# 'everyon know pasta dish complet without parmigianoreggiano dyk us parmesan make del' => food
# 'imag registr sift deep learn machinelearn' => machine learning
# 'understand futur studi past forb read artificialintellig' => machine learning
# 'make makeup love music creat miami art makeupartist artist fashion life beauti michigan' => hollywood
# 'radh updat radh salmankhan biggboss winner gautamgulati' => bollywood
# 'tottenham reveal first pictur jose mourinho club manag amp look sharper ever' => football
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'bigg boss weekendkavaarwithsalman updat johnabraham amp anilkapoor set weekendkavaar movi pro' => bigg boss
# 'amruta khanvilkar enjoi vacat famili lo angel bollywood' => bollywood
# 'convers gorgeou jumanjithenextlevel red carpet sonypictureindia hollywood mexico' => hollywood
# 'tak season itna push kiya gaya dusr mean physic violenc punish kiss bhi mila aur' => bigg boss
# 'happi mothafuckin birthdai on realest mothafuck know iloveyoufoo catch later mayb' => happy birthday
# 'novemb opt pasta veggi tomato sauc skip creamier fattier alfredo cousin' => food
# 'sky pink pinkballtest teamindia bangladeshcricket' => cricket
# 'note asylum pezoutlaw hollywood attack killer ant movi life netfl' => hollywood
# 'officeindia bollywood director interest direct prabha' => bollywood
# 'al teamindia upcom paytm seri west indi announc indvwi' => cricket
# 'cinema movi hollywood new stun mandalorian concept art demand entir coffe tabl book' => hollywood
# 'eleg personifi aishwarya rai eleg personifi aishwaryarai missworld manushichillar missphotogen' => bollywood
# 'china turn educ win race via autom machinelearn deeplearn' => machine learning
# 'seir behav like nalayak beta buzurgon jaat purana ghar tudwa naya bana deta hai bollywood' => bollywood
# 'pretti saumya support saumyatandon anita anu anitavibhuitinaryanmishra bollywood hollywood' => bollywood
# 'list top two film year decad bollywood decadeend' => bollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'know machin learn simplifi integr role data mapper drive chang' => machine learning
# 'video star kid share social media cant help blush abram bring inner artist' => bollywood
# 'dolc' => food
# 'wrest randi orton john cena tambin duelo estrella hollywood' => hollywood
# 'mskprasad give chanc ignor talent player right select thur' => cricket
# 'happi birthdai also birthdai todai rob pension' => happy birthday
# 'oliv giroud ask chelsea sold januari favourit destin remain inter offer fren' => football
# 'imelda marco natur subject lauren greenfield kingmak film hollywood' => hollywood
# 'greatest goal ever score world footbal love see mcich lampard cfc chel' => football
# 'isten ltess jtkosunkat ujpestfc ujpest hajralilak ujpestfamili anno legenda kissracvoltamen' => happy birthday
# 'beauti saumya support saumyatandon anita anu anitavibhuitinaryanmishra bollywood hollyw' => bollywood
# 'know ansibl radic simpl autom platform bigdata analyt machinelearn' => machine learning
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'kirkdborn parametr bootstrap non parametr bootstrap tradit parametr comparison on pictur' => machine learning
# 'pulipaka prevent crm garbag garbag syndrom bigdata analyt datasci machinelearn iot' => machine learning
# 'happi birthdai cha cha nehru happi children dai wish team panaroma children kid love' => happy birthday
# 'assist pujarinighosh tejaswinisinha style aishwaryabahl sejalgoy intern digit real' => bollywood
# 'among match sir never stop get game plai win long' => football
# 'todai game hurri purchas late time call whatsapp zan' => football
# 'nice plate lobster spaghetti continu dai right wai must try especi' => food
# 'weve detect power gamma rai burst record via artificialintellig' => machine learning
# 'top datasci us case trust secur bigdata machinelearn digitaltr' => machine learning
# 'india senior select committe met kolkata todai pick squad upcom tour west indi' => cricket
# 'milano andavo nepentha hollywood rider pensar che pensiero carol alt milanosecondom mitomo' => hollywood
# 'twitter pasta' => food
# 'robot humanoid emot artificialintellig robot robot machinelearn fac' => machine learning
# 'skip line order onlin italianfood dessert pasta food' => food
# 'piard robot farmer could grow food need robot agritech machinelearn agtech iot tech' => machine learning
# 'birthdai cake happi birthdai moodi cretiacak custom cake cake indi bakeri sweet sweet' => happy birthday
# 'gui todai birthdai undisput hit maker moreki malwed hit maker help wish' => bollywood
# 'amazingli brilliant valu pasta sauc nasti tomato herb add favourit veggi mea' => food
# 'fusilli porcini gamberetti insiem sapor delicati facili grand effetto ricett cucina foodblog bene' => food
# 'get pinkballtest mode teamindia indvban' => cricket
# 'democrat amp filmmak end hollywood system socialmedia creat democraci centuri' => hollywood
# 'want help win chelsea fulham donat campaign' => football
# 'sanju samson get chanc futur teamindia sanjusamson indvswi' => cricket
# 'slai still trend even year hinakhan amp biggboss cute nok jhok miss biggbo' => bigg boss
# 'daili mail chelsea fan plot frank lampard special on banner take trip tottenham former' => football
# 'aktivisten gegen rundfunkbeitrag gez sorgt ein maximal berieselung und beeinflussung de brger durch von der politik' => hollywood
# 'yuta rico happi birthdai week happi happybirth' => happy birthday
# 'bollywood celebritylif' => bollywood
# 'somebodi got stand ovat richard jewel premier hollywood everyth fell place' => hollywood
# 'pasta con tonno sugo peperoni mascarpon crear osar provar follow russo' => food
# 'sanjusamson indvswi teamindia' => cricket
# 'exposethetruth world watch wakeup sheknew illuminatiagenda hollywood' => hollywood
# 'histor test match teamindia local boi indvban pinkballtest orangearmi' => cricket
# 'teh plottr agent teh antichrist conspiraci began darwin creatd teh hoax evolushun hollywood come' => hollywood
# 'ond est boneca globalista palhao hollywood mai conhecido como ond est' => hollywood
# 'laugh addict film pleas watch indi film amazon prime veteran addict depress ptsd amp comedi' => hollywood
# 'photobi makeupartist hairstylist celebr' => happy birthday
# 'rumour troubl alreadi kane mourinho follow epl premierleagu lfc mcfc salah kane aguero sterl' => football
# 'part sai bryan wong geniu send hollywood romanc retain singa' => hollywood
# 'sposupd teamindia indv' => cricket
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'director todd phillip reportedli plan return joker sequel like reteam joaquin pho' => hollywood
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'inter giroud depaul incontro con lagent dellattaant del chelsea scelta cont ragiona cifr' => football
# 'tuesdai italian famili style dinner east pasta soup salad wine cannoli' => food
# 'al teamindia upcom seri west indi announc indvwi' => cricket
# 'feta pul biber oregano macaroni bake bazaar grab copi make todai delici comfort' => food
# 'feel home awai hustl bustl life everydai essenti factor come choos furnitu' => football
# 'make per dai autom system close sale see seo' => machine learning
# 'jose mourinho spur tottenham josemourinho footbal manchesterunit manchesterc chelsea arsen' => football
# 'octob happi birthdai kirankumpati' => happy birthday
# 'good morn koh larn chonburi eastern thailand happi sundai happi bihdai' => happy birthday
# 'pleas give big happi birthdai shout twin minni bat amp sox year old todai' => happy birthday
# 'todai birthdai feel fine happi' => happy birthday
# 'cannot suess doubt excess poeticgirl poetri poetrycommun vsspoem writer' => bollywood
# 'com strike kovac inter milan first chelsea goal still pend cfc' => football
# 'ofici tottenham confirma jo mourinho como nuevo entrenador tra chelsea manunit turno' => football
# 'live italian on hous like pasta bless' => food
# 'chelsea men word chelsea man get thrown around alot dai wether european trophi domesti' => football
# 'daili mail chelsea fan plot frank lampard special on banner take trip tottenham former' => football
# 'mourinho spur lol wow glad got job though premierleagu chelsea spur mufc footbal' => football
# 'cric msdhoni still unavail viratkohli back squad three player get drop without even get' => cricket
# 'via mikequindazzi mikequindazzi us case rank softwar revenu tractica via mikequindazzi' => machine learning
# 'that six hone cricket skill upcom film jersei shahidkapoor jersei bollywood' => bollywood
# 'bui corpor bank corpbank fintech machinelearn stock trade' => machine learning
# 'sonam kapoor send good food vibe enjoi vacai sister rhea kapoor read stori' => bollywood
# 'best version chevyqui hiphopartist hollywood hiphopn soundcloud hiphopjunki undergroundhiphop' => hollywood
# 'akb team happi birthdai' => happy birthday
# 'lindo aishwaryaraibachchan celebraron octavo cumpleao hija aaradhyabachchan' => bollywood
# 'happen work machinelearn app focus ag facial recognit cer' => machine learning
# 'yet anoth drool worthi pictur shoot baaghi bollywood bollywoodnew' => bollywood
# 'integr scienc provid cut edg verif automat machin machinelearn intoainew' => machine learning

# %%
np.mean(predicted == y_test) ## 80% sounds good only
# Out:
# 0.9459181045583311

# %%
# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
#clf = MultinomialNB().fit(X_train_tfidf, y_train)


SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(X_train_tfidf,y_train)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
